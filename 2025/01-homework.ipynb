# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Pnadas version
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ### Get the data

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv
# Out:
# --2025-11-09 20:24:13--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 874188 (854K) [text/plain]
# Saving to: ‘car_fuel_efficiency.csv.1’
#
# car_fuel_efficiency 100%[===================>] 853.70K  --.-KB/s    in 0.09s
#
# 2025-11-09 20:24:13 (9.09 MB/s) - ‘car_fuel_efficiency.csv.1’ saved [874188/874188]

# %%
df = pd.read_csv('car_fuel_efficiency.csv')
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# ...

# %%
df.shape
# Out:
# (9704, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9704 entries, 0 to 9703
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   engine_displacement  9704 non-null   int64
#  1   num_cylinders        9222 non-null   float64
#  2   horsepower           8996 non-null   float64
#  3   vehicle_weight       9704 non-null   float64
#  4   acceleration         8774 non-null   float64
#  5   model_year           9704 non-null   int64
#  6   origin               9704 non-null   object
#  7   fuel_type            9704 non-null   object
#  8   drivetrain           9704 non-null   object
#  9   num_doors            9202 non-null   float64
#  10  fuel_efficiency_mpg  9704 non-null   float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 834.1+ KB

# %%
## Types of fuel types in the dataset
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Gasoline    4898
# Diesel      4806
# Name: count, dtype: int64

# %%
## check for missing values
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
## What's the maximum fuel efficiency of cars from asia?
df.groupby('origin')['fuel_efficiency_mpg'].max()
# Out:
# origin
# Asia      23.759123
# Europe    25.967222
# USA       24.971452
# Name: fuel_efficiency_mpg, dtype: float64

# %%
df.origin.unique()
# Out:
# array(['Europe', 'USA', 'Asia'], dtype=object)

# %%
df[df['origin']=='Asia']['fuel_efficiency_mpg'].max()
# Out:
# np.float64(23.759122836520497)

# %%
df.horsepower.describe()
# Out:
# count    8996.000000
# mean      149.657292
# std        29.879555
# min        37.000000
# 25%       130.000000
# 50%       149.000000
# 75%       170.000000
# max       271.000000
# Name: horsepower, dtype: float64

# %%
# 1. Median value of horsepower column
df['horsepower'].median()
# Out:
# np.float64(149.0)

# %%
# 2. the most frequent value of the same horsepower column.
most_frequent = df['horsepower'].mode()[0]
most_frequent
# Out:
# np.float64(152.0)

# %%
# 3.0. check how many missing values are there in the horsepower column
df['horsepower'].isnull().sum()
# Out:
# np.int64(708)

# %%
# 3.0 fill the missing values in the horsepower column with the most frequent value
df['horsepower'] = df['horsepower'].fillna(most_frequent)
df['horsepower']
# Out:
# 0       159.0
# 1        97.0
# 2        78.0
# 3       152.0
# 4       140.0
#         ...
# 9699    164.0
# 9700    154.0
# 9701    138.0
# 9702    177.0
# 9703    140.0
# Name: horsepower, Length: 9704, dtype: float64

# %%
# 4.0 Calculate median value of horsepower again
df['horsepower'].median()

# Has it changed? Yes , it increased
# Out:
# np.float64(152.0)

# %% [markdown]
# ### Q7. Sum of weights

# %%
# select all the cars from Asia
df_asia = df[df['origin']=='Asia']
df_asia
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 8                     250            1.0       174.0     2714.219310
# 12                    320            5.0       145.0     2783.868974
# 14                    200            6.0       160.0     3582.687368
# 20                    150            3.0       197.0     2231.808142
# 21                    160            4.0       133.0     2659.431451
# ...                   ...            ...         ...             ...
# 9688                  260            4.0       152.0     3948.404625
# 9692                  180            3.0       188.0     3680.341381
# 9693                  280            2.0       148.0     2545.070139
# 9698                  180            1.0       131.0     3107.427820
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year origin fuel_type         drivetrain  num_doors  \
# ...

# %%
df_asia.shape
# Out:
# (3247, 11)

# %%
df_asia_filtered = df_asia[['vehicle_weight','model_year']]
df_asia_filtered
# Out:
#       vehicle_weight  model_year
# 8        2714.219310        2016
# 12       2783.868974        2010
# 14       3582.687368        2007
# 20       2231.808142        2011
# 21       2659.431451        2016
# ...              ...         ...
# 9688     3948.404625        2018
# 9692     3680.341381        2016
# 9693     2545.070139        2012
# 9698     3107.427820        2005
# 9703     2908.043477        2005
#
# [3247 rows x 2 columns]

# %%
df_matrix = df_asia_filtered.head(7)
df_matrix
# Out:
#     vehicle_weight  model_year
# 8      2714.219310        2016
# 12     2783.868974        2010
# 14     3582.687368        2007
# 20     2231.808142        2011
# 21     2659.431451        2016
# 34     2844.227534        2014
# 38     3761.994038        2019

# %% [markdown]
# Question 4

# %%
X = np.array(df_matrix)

# %% [markdown]
# Question 5

# %%
XTX = X.T.dot(X)
XTX
# Out:
# array([[62248334.33150761, 41431216.5073268 ],
#        [41431216.5073268 , 28373339.        ]])

# %% [markdown]
# Question 6
